# %%
import pandas as pd

# %%
# toric_code = pd.read_csv("toric_code.dat", delimiter=" ")
toric_code = pd.read_csv("toric_code.csv")
toric_code
# Out:
#     d    res   nq        all      init    config   cons_gen  cons_sol
# 0   4  False   32   0.130130  0.000189  0.091738   0.019201  0.019002
# 1   5  False   50   0.261013  0.000116  0.131318   0.104340  0.025239
# 2   6  False   72   0.438052  0.000135  0.160305   0.250463  0.027149
# 3   7  False   98   2.647723  0.000165  0.189066   2.422587  0.035905
# 4   8  False  128   7.742341  0.000414  0.233357   7.463762  0.044808
# 5   9  False  162  11.682326  0.001089  0.445357  11.168678  0.067202
# 6  10  False  200   2.422900  0.000616  0.388716   1.959982  0.073586

# %%
# import numpy as np
# toric_code["d"] = np.int32(np.sqrt(toric_code["nq"]/2))
# toric_code

# %%
import matplotlib.pyplot as plt
plt.style.use('tableau-colorblind10')

fig, ax = plt.subplots()

plt.rcParams.update({'font.size': 20})
plt.scatter(toric_code["nq"], toric_code["all"])
plt.plot(toric_code["nq"], toric_code["all"])

plt.title("Verifying Toric code")
plt.xlabel("Code distance (d)")
plt.ylabel("Execution Time(in sec)")
# Out:
# Text(0, 0.5, 'Execution Time(in sec)')

# %%
sc_buggy = pd.read_csv("surface_code_buggy.csv")

sc_buggy
# Out:
#     d    res   nq         all      init    config    cons_gen  cons_sol
# 0   3  False    9    0.074854  0.000111  0.057568    0.004713  0.012462
# 1   5  False   25    0.128075  0.000072  0.096722    0.017357  0.013924
# 2   7  False   49    0.488556  0.000085  0.169546    0.294125  0.024800
# 3   9  False   81    0.544980  0.000118  0.246050    0.273687  0.025125
# 4  11  False  121    7.715704  0.000145  0.357457    7.318112  0.039990
# 5  13  False  169    1.972237  0.000503  0.531474    1.391366  0.048894
# 6  15  False  225  240.886895  0.001236  0.666809  240.151990  0.066860
# 7  17  False  289   10.338000  0.000657  0.877829    9.372738  0.086776
# 8  19  False  361   12.523973  0.000296  1.105775   11.288465  0.129437
# 9  21  False  441   48.920109  0.000361  1.381170   47.377708  0.160870

# %%
import matplotlib.pyplot as plt
plt.style.use('tableau-colorblind10')

fig, ax = plt.subplots()

plt.rcParams.update({'font.size': 20})
# plt.scatter(sc_buggy["d"], sc_buggy["all"])
plt.scatter(toric_code["nq"], toric_code["all"], label="toric code")
plt.scatter(sc_buggy["nq"], sc_buggy["all"], label="surface code")


plt.title("Comparing Execution Times")
plt.xlabel("Number of Qubits (nq)")
plt.ylabel("Execution Time(in sec)")

plt.legend()

# %%
import matplotlib.pyplot as plt
plt.style.use('tableau-colorblind10')

fig, ax = plt.subplots()

plt.rcParams.update({'font.size': 20})
# plt.scatter(sc_buggy["d"], sc_buggy["all"])
plt.scatter(toric_code["d"], toric_code["all"], label="toric code")
plt.scatter(sc_buggy["d"], sc_buggy["all"], label="surface code")


plt.title("Comparing Execution Times")
plt.xlabel("Code distance (d)")
plt.ylabel("Execution Time(in sec)")

plt.legend()
